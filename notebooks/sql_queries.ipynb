# %%
import sqlite3
import pandas as pd
from pathlib import Path

BASE = Path().resolve().parent
conn = sqlite3.connect(BASE / "data" / "db" / "bluestock_mf.db")

def run_query(title, sql):
    print(f"\n{'='*55}")
    print(f" {title}")
    print('='*55)
    df = pd.read_sql_query(sql, conn)
    print(df.to_string(index=False))
    return df

# %%
run_query("Q1: Top 5 funds by AUM", """
    SELECT scheme_name, fund_house, aum_crore
    FROM fact_performance
    ORDER BY aum_crore DESC
    LIMIT 5
""")
# Out:
# ...
#  Q1: Top 5 funds by AUM
# ...
#                                           scheme_name        fund_house  aum_crore
# Mirae Asset Emerging Bluechip Fund - Regular - Growth    Mirae Asset MF      49046
#         Kotak Emerging Equity Fund - Regular - Growth Kotak Mahindra MF      47469
#        Nippon India Small Cap Fund - Regular - Growth   Nippon India MF      43630
#            DSP Top 100 Equity Fund - Regular - Growth   DSP Mutual Fund      41828
#                   UTI Mid Cap Fund - Regular - Growth   UTI Mutual Fund      41728
#                                          scheme_name         fund_house  \
# 0  Mirae Asset Emerging Bluechip Fund - Regular -...     Mirae Asset MF
# 1      Kotak Emerging Equity Fund - Regular - Growth  Kotak Mahindra MF
# 2     Nippon India Small Cap Fund - Regular - Growth    Nippon India MF
# 3         DSP Top 100 Equity Fund - Regular - Growth    DSP Mutual Fund
# 4                UTI Mid Cap Fund - Regular - Growth    UTI Mutual Fund
#
#    aum_crore
# ...

# %%
run_query("Q2: Average NAV per month (sample — SBI Bluechip)", """
    SELECT amfi_code,
           STRFTIME('%Y-%m', date) AS month,
           ROUND(AVG(nav), 4) AS avg_nav
    FROM fact_nav
    WHERE amfi_code = 119551
    GROUP BY amfi_code, month
    ORDER BY month
""")
# Out:
# ...
#  Q2: Average NAV per month (sample — SBI Bluechip)
# ...
#  amfi_code   month  avg_nav
#     119551 2022-01  55.0884
#     119551 2022-02  52.4818
#     119551 2022-03  50.8359
#     119551 2022-04  52.0363
#     119551 2022-05  51.8883
#     119551 2022-06  52.6814
#     119551 2022-07  52.6937
#     119551 2022-08  53.7734
#     119551 2022-09  56.5458
#     119551 2022-10  57.8837
#     119551 2022-11  60.8502
#     119551 2022-12  61.3497
#     119551 2023-01  60.2697
#     119551 2023-02  61.1346
#     119551 2023-03  64.5890
#     119551 2023-04  67.3590
#     119551 2023-05  66.2099
#     119551 2023-06  69.6245
#     119551 2023-07  70.8259
#     119551 2023-08  73.7556
#     119551 2023-09  74.0329
#     119551 2023-10  71.2114
#     119551 2023-11  72.8890
#     119551 2023-12  72.1944
#     119551 2024-01  68.3420
#     119551 2024-02  66.8681
#     119551 2024-03  67.3711
#     119551 2024-04  69.2138
#     119551 2024-05  72.8798
#     119551 2024-06  73.6522
# ...

# %%
run_query("Q3: SIP inflow YoY growth", """
    SELECT month,
           sip_inflow_crore,
           ROUND(yoy_growth_pct, 2) AS yoy_growth_pct
    FROM fact_sip_industry
    WHERE yoy_growth_pct IS NOT NULL
    ORDER BY month
""")
# Out:
# ...
#  Q3: SIP inflow YoY growth
# ...
#      month  sip_inflow_crore  yoy_growth_pct
# 2023-01-01             13856           20.31
# 2023-02-01             13687           19.66
# 2023-03-01             14276           15.80
# 2023-04-01             14749           24.33
# 2023-05-01             14749           20.05
# 2023-06-01             14734           20.02
# 2023-07-01             15245           25.58
# 2023-08-01             15814           24.58
# 2023-09-01             16042           23.63
# 2023-10-01             16928           29.82
# 2023-11-01             17073           28.31
# 2023-12-01             17610           29.74
# 2024-01-01             18838           35.96
# 2024-02-01             19187           40.18
# 2024-03-01             20371           42.69
# 2024-04-01             20371           38.12
# 2024-05-01             21262           44.16
# 2024-06-01             21262           44.31
# 2024-07-01             23332           53.05
# ...

# %%
run_query("Q4: Total transactions by state", """
    SELECT state,
           COUNT(*) AS total_transactions,
           SUM(amount_inr) AS total_amount_inr,
           ROUND(AVG(amount_inr), 2) AS avg_amount_inr
    FROM fact_transactions
    GROUP BY state
    ORDER BY total_amount_inr DESC
""")
# Out:
# ...
#  Q4: Total transactions by state
# ...
#          state  total_transactions  total_amount_inr  avg_amount_inr
#         Punjab                2965         315780459       106502.68
#     Tamil Nadu                2806         315177237       112322.61
# Madhya Pradesh                2931         308312493       105190.21
#      Rajasthan                2577         298645822       115888.95
#        Gujarat                2780         298358940       107323.36
#    West Bengal                2748         297182514       108145.02
#      Telangana                2718         290219284       106776.78
#          Delhi                2677         289633404       108193.28
#  Uttar Pradesh                2695         285368873       105888.26
#        Haryana                2736         279634354       102205.54
#      Karnataka                2621         273753570       104446.23
#    Maharashtra                2524         269513480       106780.30
# ...

# %%
run_query("Q5: Funds with expense_ratio < 1%", """
    SELECT scheme_name, fund_house, expense_ratio_pct, plan
    FROM dim_fund
    WHERE expense_ratio_pct < 1.0
    ORDER BY expense_ratio_pct ASC
""")
# Out:
# ...
#  Q5: Funds with expense_ratio < 1%
# ...
#                                          scheme_name               fund_house  expense_ratio_pct    plan
# Nippon India Gilt Securities Fund - Regular - Growth          Nippon India MF               0.55 Regular
#         HDFC Short Term Debt Fund - Regular - Growth         HDFC Mutual Fund               0.56 Regular
#                 Kotak Liquid Fund - Regular - Growth        Kotak Mahindra MF               0.60 Regular
#             SBI Bluechip Fund - Direct Plan - Growth          SBI Mutual Fund               0.66  Direct
#            SBI Small Cap Fund - Direct Plan - Growth          SBI Mutual Fund               0.72  Direct
#        Nippon India Large Cap Fund - Direct - Growth          Nippon India MF               0.72  Direct
#             ICICI Pru Liquid Fund - Regular - Growth      ICICI Prudential MF               0.74 Regular
#                 Axis Bluechip Fund - Direct - Growth         Axis Mutual Fund               0.75  Direct
# ...

# %%
run_query("Q6: Top 5 funds by Sharpe ratio", """
    SELECT scheme_name, fund_house, sharpe_ratio,
           return_3yr_pct, risk_grade
    FROM fact_performance
    ORDER BY sharpe_ratio DESC
    LIMIT 5
""")
# Out:
# ...
#  Q6: Top 5 funds by Sharpe ratio
# ...
#                                  scheme_name               fund_house  sharpe_ratio  return_3yr_pct risk_grade
#     ICICI Pru Liquid Fund - Regular - Growth      ICICI Prudential MF          7.68            7.68        Low
#         Kotak Liquid Fund - Regular - Growth        Kotak Mahindra MF          6.18            6.18        Low
#          ABSL Liquid Fund - Regular - Growth Aditya Birla Sun Life MF          5.14            5.14        Low
# HDFC Short Term Debt Fund - Regular - Growth         HDFC Mutual Fund          1.84            7.37        Low
# SBI Magnum Gilt Fund - Regular Plan - Growth          SBI Mutual Fund          1.52            6.07        Low
#                                     scheme_name                fund_house  \
# 0      ICICI Pru Liquid Fund - Regular - Growth       ICICI Prudential MF
# 1          Kotak Liquid Fund - Regular - Growth         Kotak Mahindra MF
# ...

# %%
run_query("Q7: AUM growth by fund house per year", """
    SELECT fund_house,
           STRFTIME('%Y', date) AS year,
           ROUND(AVG(aum_lakh_crore), 2) AS avg_aum_lakh_crore
    FROM fact_aum
    GROUP BY fund_house, year
    ORDER BY fund_house, year
""")
# Out:
# ...
#  Q7: AUM growth by fund house per year
# ...
#               fund_house year  avg_aum_lakh_crore
# Aditya Birla Sun Life MF 2022                2.81
# Aditya Birla Sun Life MF 2023                2.92
# Aditya Birla Sun Life MF 2024                3.62
# Aditya Birla Sun Life MF 2025                4.22
#         Axis Mutual Fund 2022                2.45
#         Axis Mutual Fund 2023                2.50
#         Axis Mutual Fund 2024                2.90
#         Axis Mutual Fund 2025                3.30
#          DSP Mutual Fund 2022                1.11
#          DSP Mutual Fund 2023                1.23
#          DSP Mutual Fund 2024                1.72
#          DSP Mutual Fund 2025                2.13
#         HDFC Mutual Fund 2022                4.40
#         HDFC Mutual Fund 2023                4.92
#         HDFC Mutual Fund 2024                7.14
#         HDFC Mutual Fund 2025                8.63
#      ICICI Prudential MF 2022                4.77
# ...

# %%
run_query("Q8: Transaction split — SIP vs Lumpsum vs Redemption", """
    SELECT transaction_type,
           COUNT(*) AS count,
           SUM(amount_inr) AS total_amount,
           ROUND(AVG(amount_inr), 2) AS avg_amount
    FROM fact_transactions
    GROUP BY transaction_type
""")
# Out:
# ...
#  Q8: Transaction split — SIP vs Lumpsum vs Redemption
# ...
# transaction_type  count  total_amount  avg_amount
#          Lumpsum   8095    2059821448   254456.02
#       Redemption   4967    1244525491   250558.79
#              Sip  19716     217233491    11018.13
#   transaction_type  count  total_amount  avg_amount
# 0          Lumpsum   8095    2059821448   254456.02
# 1       Redemption   4967    1244525491   250558.79
# 2              Sip  19716     217233491    11018.13

# %%
run_query("Q9: Top sectors by total portfolio weight", """
    SELECT sector,
           ROUND(SUM(weight_pct), 2) AS total_weight_pct,
           COUNT(DISTINCT amfi_code) AS num_funds
    FROM fact_portfolio
    GROUP BY sector
    ORDER BY total_weight_pct DESC
    LIMIT 10
""")
# Out:
# ...
#  Q9: Top sectors by total portfolio weight
# ...
#         sector  total_weight_pct  num_funds
#        Banking            652.26         30
#             IT            455.47         27
#         Pharma            407.45         22
#     Automobile            323.65         26
#      Utilities            265.54         19
#           FMCG            229.11         19
# Infrastructure            192.16         18
#    Diversified            169.23         14
#        Telecom            145.62         15
# Consumer Goods            127.61          9
#            sector  total_weight_pct  num_funds
# 0         Banking            652.26         30
# 1              IT            455.47         27
# 2          Pharma            407.45         22
# 3      Automobile            323.65         26
# 4       Utilities            265.54         19
# 5            FMCG            229.11         19
# 6  Infrastructure            192.16         18
# 7     Diversified            169.23         14
# ...

# %%
run_query("Q10: Best performing funds vs benchmark", """
    SELECT p.scheme_name,
           p.return_1yr_pct,
           p.benchmark_3yr_pct,
           p.alpha,
           p.sharpe_ratio,
           f.benchmark
    FROM fact_performance p
    JOIN dim_fund f ON p.amfi_code = f.amfi_code
    ORDER BY p.return_1yr_pct DESC
    LIMIT 10
""")
# Out:
# ...
#  Q10: Best performing funds vs benchmark
# ...
#                                       scheme_name  return_1yr_pct  benchmark_3yr_pct  alpha  sharpe_ratio            benchmark
#            ABSL Small Cap Fund - Regular - Growth           24.93              20.54   1.84          0.90 BSE 250 SmallCap TRI
#        SBI Small Cap Fund - Regular Plan - Growth           24.56              22.16   1.23          0.94 BSE 250 SmallCap TRI
#            Axis Small Cap Fund - Regular - Growth           21.97              20.47   0.51          0.84 BSE 250 SmallCap TRI
#    Nippon India Small Cap Fund - Regular - Growth           21.30              19.35   0.80          0.81 BSE 250 SmallCap TRI
#         SBI Small Cap Fund - Direct Plan - Growth           20.59              22.01   1.13          0.93 BSE 250 SmallCap TRI
#             DSP Small Cap Fund - Regular - Growth           20.20              19.39   0.69          0.80 BSE 250 SmallCap TRI
# ...

# %%
conn.close()
print("All 10 queries complete ✓")
# Out:
# All 10 queries complete ✓
